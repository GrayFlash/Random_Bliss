# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('C://Users/Gray/Desktop/git_repos/IPL-2020/Dummy Data/matches_complete.csv')

# %%
li = (df['team1'].unique()).astype(str)
arr = ['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020']
dict = {}
for i in range(len(li)):
    print(li[i].upper())
    dict[li[i].upper()] = i
# Out:
# KOLKATA KNIGHT RIDERS
# CHENNAI SUPER KINGS
# RAJASTHAN ROYALS
# MUMBAI INDIANS
# DECCAN CHARGERS
# KINGS XI PUNJAB
# ROYAL CHALLENGERS BANGALORE
# DELHI DAREDEVILS
# KOCHI TUSKERS KERALA
# PUNE WARRIORS
# SUNRISERS HYDERABAD
# RISING PUNE SUPERGIANTS
# GUJARAT LIONS
# RISING PUNE SUPERGIANT
# DELHI CAPITALS

# %%
percentage = (pd.DataFrame(index=[li], columns=[arr])).fillna(0)
x = np.array(percentage).astype(float)

# %%
def func_tab(season, toss_count, match_count):
    j = int(season)-2008
    for i in range(len(li)):
        if(match_count[i]!=0):
            #print(match_count)
            x[i][j] = toss_count[i]/match_count[i]
            if(j+2008 == 2019):
                print(toss_count)
                print(match_count)
            #print(x[i][j])

# %%
data = np.array(df)
toss_count = np.zeros((15,1))
match_count = np.zeros((15, 1))
prev_season = 2008
for i in range(756):
    toss_winner = df['toss_winner'][i]
    match_winner = df['winner'][i]
    season = (df['season'][i]) 
    pos = dict[toss_winner]
    if(season!=prev_season):
        func_tab(season, toss_count, match_count)
        prev_season = season
    match_count[pos] += 1
    if(match_winner==toss_winner):
        toss_count[pos] += 1
func_tab(2020, toss_count, match_count)
# Out:
# [[49.]
#  [50.]
#  [37.]
#  [50.]
#  [19.]
#  [32.]
#  [39.]
#  [35.]
#  [ 4.]
#  [ 3.]
#  [21.]
#  [ 3.]
#  [10.]
#  [ 5.]
#  [ 0.]]
# [[87.]
#  [77.]
#  [69.]
#  [90.]
#  [43.]
#  [75.]
#  [77.]
#  [80.]
#  [ 8.]
#  [20.]
#  [42.]
#  [ 7.]
#  [15.]
#  [ 6.]
#  [ 0.]]
# [[49.]
#  [50.]
#  [37.]
#  [50.]
#  [19.]
#  [32.]
#  [39.]
#  [35.]
#  [ 4.]
#  [ 3.]
#  [21.]
#  [ 3.]
#  [10.]
#  [ 5.]
#  [ 0.]]
# [[87.]
#  [77.]
#  [69.]
#  [90.]
#  [43.]
#  [75.]
#  [77.]
#  [80.]
#  [ 8.]
#  [20.]
#  [42.]
#  [ 7.]
#  [15.]
#  [ 6.]
#  [ 0.]]
# [[49.]
#  [50.]
#  [37.]
#  [50.]
#  [19.]
#  [32.]
#  [39.]
#  [35.]
#  [ 4.]
#  [ 3.]
#  [21.]
#  [ 3.]
#  [10.]
#  [ 5.]
#  [ 0.]]
# [[87.]
#  [77.]
#  [69.]
#  [90.]
#  [43.]
#  [75.]
#  [77.]
#  [80.]
#  [ 8.]
#  [20.]
#  [42.]
#  [ 7.]
#  [15.]
#  [ 6.]
#  [ 0.]]
# [[49.]
#  [50.]
#  [37.]
#  [50.]
#  [19.]
#  [32.]
#  [39.]
#  [35.]
#  [ 4.]
#  [ 3.]
#  [21.]
#  [ 3.]
#  [10.]
#  [ 5.]
#  [ 0.]]
# [[87.]
#  [77.]
#  [69.]
#  [90.]
#  [43.]
# ...

# %%
x
# Out:
# array([[0.        , 0.5       , 0.38461538, 0.45      , 0.51851852,
#         0.55882353, 0.5       , 0.52727273, 0.53968254, 0.55072464,
#         0.56410256, 0.56321839, 0.57608696],
#        [0.        , 0.6       , 0.58333333, 0.59090909, 0.64516129,
#         0.63157895, 0.67391304, 0.66071429, 0.63636364, 0.63636364,
#         0.63636364, 0.64935065, 0.64044944],
#        [0.        , 0.81818182, 0.73333333, 0.66666667, 0.64285714,
#         0.55263158, 0.55102041, 0.54385965, 0.53968254, 0.53968254,
#         0.53968254, 0.53623188, 0.525     ],
#        [0.        , 0.5       , 0.5       , 0.56521739, 0.55172414,
#         0.55      , 0.57692308, 0.56896552, 0.55384615, 0.55405405,
#         0.56470588, 0.55555556, 0.57142857],
#        [0.        , 0.22222222, 0.47368421, 0.5       , 0.5       ,
#         0.44186047, 0.44186047, 0.44186047, 0.44186047, 0.44186047,
#         0.44186047, 0.44186047, 0.44186047],
# ...

# %%
percentage = (pd.DataFrame(x, index=[li], columns=[arr])).fillna(0)

# %%
df['Match Won after winning Toss Team A'] = 't'
df['Match Won after winning Toss Team B'] = 't'

# %%
for i in range(756):
    season = df['season'][i]
    teamA = df['team1'][i]
    teamB = df['team2'][i]
    diff = int(season)-2008
    posA = dict[teamA]
    posB = dict[teamB]
    df['Match Won after winning Toss Team A'][i] = x[posA][diff]
    df['Match Won after winning Toss Team B'][i] = x[posB][diff]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
percentage.to_csv("MatchWonAfterWinningToss.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  id  season        city        date                  team1  \
# 0           0  60    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1           1  61    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2           2  62    2008       Delhi  2008-04-19       Rajasthan Royals
# 3           3  63    2008      Mumbai  2008-04-20         Mumbai Indians
# 4           4  64    2008     Kolkata  2008-04-20        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  ...                                       venue    umpire1  \
# ...

# %%
df.to_csv("matches_complete.csv")

# %%
percentage
# Out:
#                             2008      2009      2010      2011      2012  \
# Kolkata Knight Riders        0.0  0.500000  0.384615  0.450000  0.518519
# Chennai Super Kings          0.0  0.600000  0.583333  0.590909  0.645161
# Rajasthan Royals             0.0  0.818182  0.733333  0.666667  0.642857
# Mumbai Indians               0.0  0.500000  0.500000  0.565217  0.551724
# Deccan Chargers              0.0  0.222222  0.473684  0.500000  0.500000
# Kings XI Punjab              0.0  0.500000  0.571429  0.421053  0.413793
# Royal Challengers Bangalore  0.0  0.200000  0.461538  0.421053  0.520000
# Delhi Daredevils             0.0  0.333333  0.533333  0.565217  0.500000
# Kochi Tuskers Kerala         0.0  0.000000  0.000000  0.000000  0.500000
# Pune Warriors                0.0  0.000000  0.000000  0.000000  0.000000
# Sunrisers Hyderabad          0.0  0.000000  0.000000  0.000000  0.000000
# Rising Pune Supergiants      0.0  0.000000  0.000000  0.000000  0.000000
# ...

# %%
match_count
# Out:
# array([[92.],
#        [89.],
#        [80.],
#        [98.],
#        [43.],
#        [81.],
#        [81.],
#        [80.],
#        [ 8.],
#        [20.],
#        [46.],
#        [ 7.],
#        [15.],
#        [ 6.],
#        [10.]])

# %%
toss_count
# Out:
# array([[53.],
#        [57.],
#        [42.],
#        [56.],
#        [19.],
#        [35.],
#        [41.],
#        [35.],
#        [ 4.],
#        [ 3.],
#        [23.],
#        [ 3.],
#        [10.],
#        [ 5.],
#        [ 7.]])

# %%
x[14][12] = 42/90

# %%
x[14][12]
# Out:
# 0.4666666666666667

# %%
df1 = pd.read_csv('C://Users/Gray/Desktop/git_repos/IPL-2020/Dummy Data/2020_done.csv')

# %%
df1
# Out:
#     Unnamed: 0  match_day  match_no  day time_IST time_UAE      venue  \
# 0            0          1         1  SAT   7:30PM   6:00PM  ABU DHABI
# 1            1          2         2  SUN   7:30PM   6:00PM      DUBAI
# 2            2          3         3  MON   7:30PM   6:00PM      DUBAI
# 3            3          4         4  TUE   7:30PM   6:00PM    SHARJAH
# 4            4          5         5  WED   7:30PM   6:00PM  ABU DHABI
# 5            5          6         6  THU   7:30PM   6:00PM      DUBAI
# 6            6          7         7  FRI   7:30PM   6:00PM      DUBAI
# 7            7          8         8  SAT   7:30PM   6:00PM  ABU DHABI
# 8            8          9         9  SUN   7:30PM   6:00PM    SHARJAH
# 9            9         10        10  MON   7:30PM   6:00PM      DUBAI
# 10          10         11        11  TUE   7:30PM   6:00PM  ABU DHABI
# 11          11         12        12  WED   7:30PM   6:00PM      DUBAI
# ...

# %%
df1['Match Won after winning Toss Team A'] = 't'
df1['Match Won after winning Toss Team B'] = 't'

# %%
for i in range(56):
    season = 2020
    teamA = df1['home'][i]
    teamB = df1['away'][i]
    diff = int(season)-2008
    posA = dict[teamA]
    posB = dict[teamB]
    df1['Match Won after winning Toss Team A'][i] = x[posA][diff]
    df1['Match Won after winning Toss Team B'][i] = x[posB][diff]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
df1
# Out:
#     Unnamed: 0  match_day  match_no  day time_IST time_UAE      venue  \
# 0            0          1         1  SAT   7:30PM   6:00PM  ABU DHABI
# 1            1          2         2  SUN   7:30PM   6:00PM      DUBAI
# 2            2          3         3  MON   7:30PM   6:00PM      DUBAI
# 3            3          4         4  TUE   7:30PM   6:00PM    SHARJAH
# 4            4          5         5  WED   7:30PM   6:00PM  ABU DHABI
# 5            5          6         6  THU   7:30PM   6:00PM      DUBAI
# 6            6          7         7  FRI   7:30PM   6:00PM      DUBAI
# 7            7          8         8  SAT   7:30PM   6:00PM  ABU DHABI
# 8            8          9         9  SUN   7:30PM   6:00PM    SHARJAH
# 9            9         10        10  MON   7:30PM   6:00PM      DUBAI
# 10          10         11        11  TUE   7:30PM   6:00PM  ABU DHABI
# 11          11         12        12  WED   7:30PM   6:00PM      DUBAI
# ...

# %%
df1.to_csv('2020_done.csv', index=False)
