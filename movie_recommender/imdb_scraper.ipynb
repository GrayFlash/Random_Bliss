# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
from tabulate import tabulate

def response_await(url):
    response = urlopen(url)
    data = response.read()
    soup = BeautifulSoup(data, 'lxml')
    return soup

def choices():
    options_map = {
        1: ('Top movies' , 'top'),
        2: ('Most Popular Movies' , 'moviemeter'),
        3: ('Top English Movies' , 'top-english-movies'),
        4: ('Top TV Shows' , 'toptv'),
        5: ('Most Popular TV Shows' , 'tvmeter'),
        6: ('Low Rated Movies', 'bottom'),
        7: ('Top Box Office collection', 'boxoffice')
    }
    
    for i, option in enumerate(options_map, 1):
        print("{}) {} ".format(i, options_map[option][0]))
        
    choice = int(input('\n\n Please Enter your Choice: \n'))
    while(choice<1 or choice>len(options_map)):
        print("\n Invalid Choice")
        choice = int(input('\n\n Please Enter your Choice: \n'))
        
    return options_map[choice][1]

def getData(base_url, option):
    complete_url =base_url + option
    soup = response_await(complete_url)
    card_list = soup.find_all('span',{'class':'media-body media-vertical-align'})
    result=[]
    count = 1
    for card in card_list:
        try:
            name = card.find('h4').text.replace("\n"," ").lstrip("0123456789. ")
        except:
            pass
        try:
            rating = card.find('p').text.strip()
        except:
            pass
        
        result.append([count, name, rating])
        count += 1
        
    print(tabulate(result, headers=["Index", "Name", "Ratings"], tablefmt="grid"))
    

def main():
    base_url = "http://m.imdb.com/chart/"
    choice = choices()
    getData(base_url, choice)
    
if __name__ == '__main__':
    main()
# Out:
# 1) Top movies
# 2) Most Popular Movies
# 3) Top English Movies
# 4) Top TV Shows
# 5) Most Popular TV Shows
# 6) Low Rated Movies
# 7) Top Box Office collection
#
#
#  Please Enter your Choice:
# 5
# +---------+------------------------------------------+-----------+
# |   Index | Name                                     |   Ratings |
# +=========+==========================================+===========+
# |       1 | Cursed (2020)                            |       5.8 |
# +---------+------------------------------------------+-----------+
# |       2 | Dark (2017)                              |       8.8 |
# +---------+------------------------------------------+-----------+
# |       3 | Perry Mason (2020)                       |       7.4 |
# +---------+------------------------------------------+-----------+
# |       4 | Yellowstone (2018)                       |       8.5 |
# +---------+------------------------------------------+-----------+
# |       5 | Game of Thrones (2011)                   |       9.3 |
# +---------+------------------------------------------+-----------+
# |       6 | Warrior Nun (2020)                       |       6.9 |
# +---------+------------------------------------------+-----------+
# |       7 | Kingdom (2014)                           |       8.4 |
# +---------+------------------------------------------+-----------+
# |       8 | Brave New World (2020)                   |       7   |
# +---------+------------------------------------------+-----------+
# |       9 | The Boys (2019)                          |       8.7 |
# +---------+------------------------------------------+-----------+
# |      10 | The Office (2005)                        |       8.9 |
# +---------+------------------------------------------+-----------+
# |      11 | The 100 (2014)                           |       7.7 |
# +---------+------------------------------------------+-----------+
# |      12 | Lucifer (2016)                           |       8.2 |
# +---------+------------------------------------------+-----------+
# |      13 | Grey's Anatomy (2005)                    |       7.6 |
# +---------+------------------------------------------+-----------+
# |      14 | Community (2009)                         |       8.5 |
# +---------+------------------------------------------+-----------+
# |      15 | Vikings (2013)                           |       8.5 |
# +---------+------------------------------------------+-----------+
# |      16 | Breaking Bad (2008)                      |       9.5 |
# +---------+------------------------------------------+-----------+
# |      17 | Glee (2009)                              |       6.7 |
# +---------+------------------------------------------+-----------+
# |      18 | Criminal Minds (2005)                    |       8.1 |
# +---------+------------------------------------------+-----------+
# |      19 | Supernatural (2005)                      |       8.4 |
# +---------+------------------------------------------+-----------+
# |      20 | The Umbrella Academy (2019)              |       8   |
# +---------+------------------------------------------+-----------+
# |      21 | Snowpiercer (2020)                       |       6.7 |
# +---------+------------------------------------------+-----------+
# |      22 | The Alienist (2018)                      |       7.7 |
# +---------+------------------------------------------+-----------+
# |      23 | The Walking Dead (2010)                  |       8.2 |
# +---------+------------------------------------------+-----------+
# |      24 | Dark Desire (2020)                       |       6.4 |
# +---------+------------------------------------------+-----------+
# |      25 | Ozark (2017)                             |       8.4 |
# +---------+------------------------------------------+-----------+
# |      26 | Friends (1994)                           |       8.9 |
# +---------+------------------------------------------+-----------+
# |      27 | Agents of S.H.I.E.L.D. (2013)            |       7.5 |
# +---------+------------------------------------------+-----------+
# |      28 | Hanna (2019)                             |       7.5 |
# +---------+------------------------------------------+-----------+
# |      29 | Suits (2011)                             |       8.5 |
# +---------+------------------------------------------+-----------+
# |      30 | Peaky Blinders (2013)                    |       8.8 |
# +---------+------------------------------------------+-----------+
# |      31 | Stranger Things (2016)                   |       8.8 |
# +---------+------------------------------------------+-----------+
# |      32 | Absentia (2017)                          |       7.3 |
# +---------+------------------------------------------+-----------+
# |      33 | Vikingane (2016)                         |       7.8 |
# +---------+------------------------------------------+-----------+
# |      34 | Schitt's Creek (2015)                    |       8.4 |
# +---------+------------------------------------------+-----------+
# |      35 | Doom Patrol (2019)                       |       8   |
# +---------+------------------------------------------+-----------+
# |      36 | Money Heist (2017)                       |       8.4 |
# +---------+------------------------------------------+-----------+
# |      37 | Modern Family (2009)                     |       8.4 |
# +---------+------------------------------------------+-----------+
# |      38 | In the Dark (2019)                       |       7.4 |
# +---------+------------------------------------------+-----------+
# |      39 | The Big Bang Theory (2007)               |       8.1 |
# +---------+------------------------------------------+-----------+
# |      40 | The Sopranos (1999)                      |       9.2 |
# +---------+------------------------------------------+-----------+
# |      41 | The Last Kingdom (2015)                  |       8.4 |
# +---------+------------------------------------------+-----------+
# |      42 | Avatar: The Last Airbender (2005)        |       9.2 |
# +---------+------------------------------------------+-----------+
# |      43 | Outlander (2014)                         |       8.4 |
# +---------+------------------------------------------+-----------+
# |      44 | Sons of Anarchy (2008)                   |       8.6 |
# +---------+------------------------------------------+-----------+
# |      45 | The Sinner (2017)                        |       8   |
# +---------+------------------------------------------+-----------+
# |      46 | Black Mirror (2011)                      |       8.8 |
# +---------+------------------------------------------+-----------+
# |      47 | Brooklyn Nine-Nine (2013)                |       8.4 |
# +---------+------------------------------------------+-----------+
# |      48 | New Girl (2011)                          |       7.7 |
# +---------+------------------------------------------+-----------+
# |      49 | The Blacklist (2013)                     |       8   |
# +---------+------------------------------------------+-----------+
# |      50 | Breathe: Into the Shadows (2020)         |       7.8 |
# +---------+------------------------------------------+-----------+
# |      51 | Westworld (2016)                         |       8.7 |
# +---------+------------------------------------------+-----------+
# |      52 | Stateless (2020)                         |       7.5 |
# +---------+------------------------------------------+-----------+
# |      53 | Law & Order: Special Victims Unit (1999) |       8   |
# +---------+------------------------------------------+-----------+
# |      54 | Lost (2004)                              |       8.3 |
# +---------+------------------------------------------+-----------+
# |      55 | Better Call Saul (2015)                  |       8.7 |
# +---------+------------------------------------------+-----------+
# |      56 | The Witcher (2019)                       |       8.2 |
# +---------+------------------------------------------+-----------+
# |      57 | The Mandalorian (2019)                   |       8.7 |
# +---------+------------------------------------------+-----------+
# |      58 | Stargirl (2020)                          |       7.3 |
# +---------+------------------------------------------+-----------+
# |      59 | NCIS (2003)                              |       7.8 |
# +---------+------------------------------------------+-----------+
# |      60 | Parks and Recreation (2009)              |       8.6 |
# +---------+------------------------------------------+-----------+
# |      61 | American Horror Story (2011)             |       8   |
# +---------+------------------------------------------+-----------+
# |      62 | The Vampire Diaries (2009)               |       7.7 |
# +---------+------------------------------------------+-----------+
# |      63 | Hannibal (2013)                          |       8.5 |
# +---------+------------------------------------------+-----------+
# |      64 | Reasons Why (2017)                       |       7.7 |
# +---------+------------------------------------------+-----------+
# |      65 | The Handmaid's Tale (2017)               |       8.5 |
# +---------+------------------------------------------+-----------+
# |      66 | Mindhunter (2017)                        |       8.6 |
# +---------+------------------------------------------+-----------+
# |      67 | Fargo (2014)                             |       8.9 |
# +---------+------------------------------------------+-----------+
# |      68 | House (2004)                             |       8.7 |
# +---------+------------------------------------------+-----------+
# |      69 | Shameless (2011)                         |       8.6 |
# +---------+------------------------------------------+-----------+
# |      70 | The Wire (2002)                          |       9.3 |
# +---------+------------------------------------------+-----------+
# |      71 | Buffy the Vampire Slayer (1997)          |       8.2 |
# +---------+------------------------------------------+-----------+
# |      72 | Homeland (2011)                          |       8.3 |
# +---------+------------------------------------------+-----------+
# |      73 | Blindspot (2015)                         |       7.4 |
# +---------+------------------------------------------+-----------+
# |      74 | Dexter (2006)                            |       8.6 |
# +---------+------------------------------------------+-----------+
# |      75 | How I Met Your Mother (2005)             |       8.3 |
# +---------+------------------------------------------+-----------+
# |      76 | How to Sell Drugs Online (Fast) (2019)   |       7.9 |
# +---------+------------------------------------------+-----------+
# |      77 | Queen of the South (2016)                |       7.9 |
# +---------+------------------------------------------+-----------+
# |      78 | Sherlock (2010)                          |       9.1 |
# +---------+------------------------------------------+-----------+
# |      79 | Doctor Who (2005)                        |       8.6 |
# +---------+------------------------------------------+-----------+
# |      80 | Prison Break (2005)                      |       8.3 |
# +---------+------------------------------------------+-----------+
# |      81 | Downton Abbey (2010)                     |       8.7 |
# +---------+------------------------------------------+-----------+
# |      82 | His Dark Materials (2019)                |       7.9 |
# +---------+------------------------------------------+-----------+
# |      83 | Fear City: New York vs the Mafia (2020)  |       7.2 |
# +---------+------------------------------------------+-----------+
# |      84 | How to Get Away with Murder (2014)       |       8.1 |
# +---------+------------------------------------------+-----------+
# |      85 | The Crown (2016)                         |       8.7 |
# +---------+------------------------------------------+-----------+
# |      86 | Psych (2006)                             |       8.3 |
# +---------+------------------------------------------+-----------+
# |      87 | Midsomer Murders (1997)                  |       7.7 |
# +---------+------------------------------------------+-----------+
# |      88 | The Flash (2014)                         |       7.7 |
# +---------+------------------------------------------+-----------+
# |      89 | Billions (2016)                          |       8.4 |
# +---------+------------------------------------------+-----------+
# |      90 | Bones (2005)                             |       7.8 |
# +---------+------------------------------------------+-----------+
# |      91 | Rick and Morty (2013)                    |       9.2 |
# +---------+------------------------------------------+-----------+
# |      92 | Gilmore Girls (2000)                     |       8.1 |
# +---------+------------------------------------------+-----------+
# |      93 | Once Upon a Time (2011)                  |       7.7 |
# +---------+------------------------------------------+-----------+
# |      94 | Star Trek: The Next Generation (1987)    |       8.6 |
# +---------+------------------------------------------+-----------+
# |      95 | The Order (2019)                         |       6.8 |
# +---------+------------------------------------------+-----------+
# |      96 | Little Fires Everywhere (2020)           |       7.8 |
# +---------+------------------------------------------+-----------+
# |      97 | The Last Dance (2020)                    |       9.2 |
# +---------+------------------------------------------+-----------+
# |      98 | Mad Men (2007)                           |       8.6 |
# +---------+------------------------------------------+-----------+
# |      99 | True Detective (2014)                    |       9   |
# +---------+------------------------------------------+-----------+
# |     100 | It's Always Sunny in Philadelphia (2005) |       8.8 |
# +---------+------------------------------------------+-----------+
